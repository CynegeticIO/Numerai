# %% [markdown]
# Created by Joan-Marc Fisa
#
# - Numerai: [FisaGol](https://numer.ai/fisagol)
#
# - Twitter: [@fisagol](https://twitter.com/fisagol)

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !pip install numerapi
# !pip install vecstack;
# Out:
# Collecting numerapi
#   Downloading numerapi-2.7.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from numerapi) (1.1.5)
# Requirement already satisfied: tqdm>=4.29.1 in /usr/local/lib/python3.7/dist-packages (from numerapi) (4.62.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from numerapi) (2018.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from numerapi) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from numerapi) (2.8.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from numerapi) (7.1.2)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->numerapi) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->numerapi) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->numerapi) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->numerapi) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->numerapi) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->numerapi) (3.0.4)
# Installing collected packages: numerapi
# Successfully installed numerapi-2.7.0
# Collecting vecstack
#   Downloading vecstack-0.4.0.tar.gz (18 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.7/dist-packages (from vecstack) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->vecstack) (1.0.1)
# Building wheels for collected packages: vecstack
#   Building wheel for vecstack (setup.py) ... done
#   Created wheel for vecstack: filename=vecstack-0.4.0-py3-none-any.whl size=19878 sha256=731367573ee7fe9cbde3bdf5b2cf7ed4dde3ea6f18d0f503d3dabead9a5c14be
#   Stored in directory: /root/.cache/pip/wheels/28/fe/0c/fe8e43660e3316d7ce204e59a79a72246c0ae9b6c5c79841c8
# Successfully built vecstack
# Installing collected packages: vecstack
# Successfully installed vecstack-0.4.0

# %%
##################################################################
##################### LIBRARIES ##################################
##################################################################

# %%
import os
import gc
import csv
import sys
import glob
import time
from pathlib import Path
from multiprocessing import Pool

import numerapi

import scipy
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import sklearn
from sklearn import (
    feature_extraction, feature_selection, decomposition, linear_model,
    model_selection, metrics, svm, preprocessing, utils
)
from sklearn.preprocessing import StandardScaler,MinMaxScaler, OrdinalEncoder, LabelEncoder,OneHotEncoder
from keras.models import Sequential, model_from_json, load_model
from keras.layers import Dense, Dropout, Activation,LSTM,Bidirectional, MaxPooling2D, Flatten,GRU
from keras.regularizers import l2
from sklearn.model_selection import StratifiedKFold, GroupKFold, GridSearchCV,cross_val_score,KFold, RepeatedStratifiedKFold,train_test_split
from sklearn.metrics import log_loss, make_scorer, mean_squared_error,classification_report,accuracy_score
from keras.utils import np_utils 
from sklearn import preprocessing
from xgboost import XGBRegressor 
from sklearn.cluster import KMeans
import matplotlib as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler,MinMaxScaler

import math
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, BaggingRegressor
from sklearn.linear_model import SGDRegressor
from lightgbm import LGBMRegressor
from sklearn.tree import DecisionTreeRegressor 

import torch.nn as nn
import torch.nn.functional as F
import torch
from vecstack import stacking

from sklearn import metrics

def RMSLE(y, pred):
    return metrics.mean_squared_error(y, pred) ** 0.5

# %%
##############################################################################
########################## DOWLOAD DATA ######################################
##############################################################################

# %%
TOURNAMENT_NAME = "nomi"
TARGET_NAME = f"target"
PREDICTION_NAME = f"prediction"

BENCHMARK = 0
BAND = 0.2

# %%
seed = 1
rand = np.random.seed(seed)

# %%
napi = numerapi.NumerAPI(verbosity="info")

napi.download_current_dataset(unzip=True)

current_ds = napi.get_current_round()
latest_round = os.path.join('numerai_dataset_'+str(current_ds))
# Out:
# 2021-08-28 18:10:32,272 INFO numerapi.utils: starting download
# ./numerai_dataset_279.zip: 100%|█████████▉| 418M/419M [00:31<00:00, 12.3MB/s]2021-08-28 18:11:04,295 INFO numerapi.base_api: unzipping file...
# ./numerai_dataset_279.zip: 419MB [00:49, 12.3MB/s]

# %%
##################################################################
##################### LOAD DATA ##################################
##################################################################

# %%
# %%time
print("# Loading data...")

training_data = pd.read_csv(os.path.join(latest_round, "numerai_training_data.csv")).set_index("id")
tournament_data = pd.read_csv(os.path.join(latest_round, "numerai_tournament_data.csv")).set_index("id")
validation_data = tournament_data[tournament_data.data_type == "validation"]

print("# All Loaded...")
# Out:
# # Loading data...
# ./numerai_dataset_279.zip: 419MB [00:54, 7.68MB/s]
# # All Loaded...
# CPU times: user 1min 8s, sys: 16.1 s, total: 1min 24s
# Wall time: 1min 26s

# %%
feature_names = [f for f in training_data.columns if f.startswith("feature")]
print(f"Loaded {len(feature_names)} features")
# Out:
# Loaded 310 features

# %%
X = training_data[feature_names]
Y = training_data[training_data.columns[-1]]

le = LabelEncoder()
Y_enc = le.fit_transform(Y)

# %%
#############################################################################
###########################  CREATING SOME MODELS  ##########################
#############################################################################

# %%
# %%time

model = GradientBoostingRegressor(random_state=rand)
model.fit(training_data[feature_names], training_data[TARGET_NAME])
gc.collect()
# Out:
# CPU times: user 28min 7s, sys: 897 ms, total: 28min 7s
# Wall time: 28min

# %%
y_pred_model = model.predict(tournament_data[feature_names])
gc.collect()

tournament_data[PREDICTION_NAME] = y_pred_model

# %%
tournament_data[PREDICTION_NAME]
# Out:
# id
# n0003aa52cab36c2    0.488127
# n000920ed083903f    0.490204
# n0038e640522c4a6    0.522209
# n004ac94a87dc54b    0.503401
# n0052fe97ea0c05f    0.501119
#                       ...
# nffd1cda0c61ecdb    0.504454
# nffd711b0e6007e3    0.505101
# nffd8a4d389df16a    0.498968
# nffdec2abd3d4c1e    0.506943
# nfff8751e4f86103    0.497827
# Name: prediction, Length: 1800934, dtype: float64

# %%
##############################################################################
######################### MAKE SUBMISSION #################################### 
##############################################################################

# %%
import numerapi
import torch
from torch.nn import Linear
from torch.nn import Sequential
from torch.functional import F

# %%
def exposures(x, y):
    x = x - x.mean(dim=0)
    x = x / x.norm(dim=0)
    y = y - y.mean(dim=0)
    y = y / y.norm(dim=0)
    return torch.matmul(x.T, y)

def reduce_exposure(prediction, features, max_exp):
    # linear model of features that will be used to partially neutralize predictions
    lin = Linear(features.shape[1],  1, bias=False)
    lin.weight.data.fill_(0.)
    model = Sequential(lin)
    optimizer = torch.optim.Adamax(model.parameters(), lr=1e-4)
    feats = torch.tensor(np.float32(features)-.5)
    pred = torch.tensor(np.float32(prediction))
    start_exp = exposures(feats, pred[:,None])
    # set target exposure for each feature to be <= current exposure
    # if current exposure is less than max_exp, or <= max_exp if  
    # current exposure is > max_exp
    targ_exp = torch.clamp(start_exp, -max_exp, max_exp)

    for i in range(100000):
        optimizer.zero_grad()
        # calculate feature exposures of current linear neutralization
        exps = exposures(feats, pred[:,None]-model(feats))
        # loss is positive when any exposures exceed their target
        loss = (F.relu(F.relu(exps)-F.relu(targ_exp)) + F.relu(F.relu(-exps)-F.relu(-targ_exp))).sum()
        print(f'       loss: {loss:0.7f}', end='\r')
        if loss < 1e-7:
            neutralizer = [p.detach().numpy() for p in model.parameters()]
            neutralized_pred = pred[:,None]-model(feats)
            break
        loss.backward()
        optimizer.step()
    return neutralized_pred, neutralizer

def reduce_all_exposures(df, column, neutralizers=[],
                                     normalize=True,
                                     gaussianize=True,
                                     era_col="era",
                                     max_exp=0.1):
    unique_eras = df[era_col].unique()
    computed = []
    for u in unique_eras:
        print(u, '\r')
        df_era = df[df[era_col] == u]
        scores = df_era[column].values
        exposure_values = df_era[neutralizers].values
        
        if normalize:
            scores2 = []
            for x in scores.T:
                x = (scipy.stats.rankdata(x, method='ordinal') - .5) / len(x)
                if gaussianize:
                    x = scipy.stats.norm.ppf(x)
                scores2.append(x)
            scores = np.array(scores2)[0]

        scores, neut = reduce_exposure(scores, exposure_values, max_exp)

        scores /= scores.std()

        computed.append(scores.detach().numpy())

    return pd.DataFrame(np.concatenate(computed), columns=column, index=df.index)

# %%
tournament_data[PREDICTION_NAME]
# Out:
# id
# n0003aa52cab36c2    0.488127
# n000920ed083903f    0.490204
# n0038e640522c4a6    0.522209
# n004ac94a87dc54b    0.503401
# n0052fe97ea0c05f    0.501119
#                       ...
# nffd1cda0c61ecdb    0.504454
# nffd711b0e6007e3    0.505101
# nffd8a4d389df16a    0.498968
# nffdec2abd3d4c1e    0.506943
# nfff8751e4f86103    0.497827
# Name: prediction, Length: 1800934, dtype: float64

# %%
data_rfe_10 = reduce_all_exposures(tournament_data,
                                   [PREDICTION_NAME],
                                   neutralizers=feature_names,
                                   era_col="era",
                                   max_exp=0.05)
# Out:
# era121
# era122
# era123
# era124
# era125
# era126
# era127
# era128
# era129
# era130
# era131
# era132
# era575
# era576
# era577
# era578
# era579
# era580
# era581
# era582
# era583
# era584
# era585
# era586
# era587
# era588
# era589
# era590
# era591
# era592
# era593
# era594
# era595
# era596
# era597
# era598
# era599
# era600
# era601
# era602
# era603
# era604
# era605
# era606
# era607
# era608
# era609
# era610
# era611
# era612
# era613
# era614
# era615
# era616
# era617
# era618
# era619
# era620
# era621
# era622
# era623
# era624
# era625
# era626
# era627
# era628
# era629
# era630
# era631
# era632
# era633
# era634
# era635
# era636
# era637
# era638
# era639
# era640
# era641
# era642
# era643
# era644
# era645
# era646
# era647
# era648
# era649
# era650
# era651
# era652
# era653
# era654
# era655
# era656
# era657
# era658
# era659
# era660
# era661
# era662
# era663
# era664
# era665
# era666
# era667
# era668
# era669
# era670
# era671
# era672
# era673
# era674
# era675
# era676
# era677
# era678
# era679
# era680
# era681
# era682
# era683
# era684
# era685
# era686
# era687
# era688
# era689
# era690
# era691
# era692
# era693
# era694
# era695
# era696
# era697
# era698
# era699
# era700
# era701
# era702
# era703
# era704
# era705
# era706
# era707
# era708
# era709
# era710
# era711
# era712
# era713
# era714
# era715
# era716
# era717
# era718
# era719
# era720
# era721
# era722
# era723
# era724
# era725
# era726
# era727
# era728
# era729
# era730
# era731
# era732
# era733
# era734
# era735
# era736
# era737
# era738
# era739
# era740
# era741
# era742
# era743
# era744
# era745
# era746
# era747
# era748
# era749
# era750
# era751
# era752
# era753
# era754
# era755
# era756
# era757
# era758
# era759
# era760
# era761
# era762
# era763
# era764
# era765
# era766
# era767
# era768
# era769
# era770
# era771
# era772
# era773
# era774
# era775
# era776
# era777
# era778
# era779
# era780
# era781
# era782
# era783
# era784
# era785
# era786
# era787
# era788
# era789
# era790
# era791
# era792
# era793
# era794
# era795
# era796
# era797
# era798
# era799
# era800
# era801
# era802
# era803
# era804
# era805
# era806
# era807
# era808
# era809
# era810
# era811
# era812
# era813
# era814
# era815
# era816
# era817
# era818
# era819
# era820
# era821
# era822
# era823
# era824
# era825
# era826
# era827
# era828
# era829
# era830
# era831
# era832
# era833
# era834
# era835
# era836
# era837
# era838
# era839
# era840
# era841
# era842
# era843
# era844
# era845
# era846
# era847
# era848
# era849
# era850
# era851
# era852
# era197
# era198
# era199
# era200
# era201
# era202
# era203
# era204
# era205
# era206
# era207
# era208
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-618863b2a706> in <module>()
#       3                                    neutralizers=feature_names,
#       4                                    era_col="era",
# ----> 5                                    max_exp=0.05)
#
# <ipython-input-19-bb2093f3867a> in reduce_all_exposures(df, column, neutralizers, normalize, gaussianize, era_col, max_exp)
#      57             scores = np.array(scores2)[0]
#      58
# ---> 59         scores, neut = reduce_exposure(scores, exposure_values, max_exp)
#      60
#      61         scores /= scores.std()
#
# <ipython-input-19-bb2093f3867a> in reduce_exposure(prediction, features, max_exp)
#      23         optimizer.zero_grad()
#      24         # calculate feature exposures of current linear neutralization
# ---> 25         exps = exposures(feats, pred[:,None]-model(feats))
#      26         # loss is positive when any exposures exceed their target
#      27         loss = (F.relu(F.relu(exps)-F.relu(targ_exp)) + F.relu(F.relu(-exps)-F.relu(-targ_exp))).sum()
#
# <ipython-input-19-bb2093f3867a> in exposures(x, y)
#       1 def exposures(x, y):
# ----> 2     x = x - x.mean(dim=0)
#       3     x = x / x.norm(dim=0)
#       4     y = y - y.mean(dim=0)
#       5     y = y / y.norm(dim=0)
#
# KeyboardInterrupt:

# %%
# replace prediction with reduced feature exposure prediction and rescale to [0,1]
tournament_data[PREDICTION_NAME] = data_rfe_10[PREDICTION_NAME]
tournament_data[PREDICTION_NAME] -= tournament_data[PREDICTION_NAME].min()
tournament_data[PREDICTION_NAME] /= tournament_data[PREDICTION_NAME].max()

# %%
tournament_data[PREDICTION_NAME]

# %%
##############################################################################
######################### MAKE SUBMISSION #################################### 
##############################################################################

# %%
tournament_data[PREDICTION_NAME].to_csv('BeeChain_3.csv')

# !cp BeeChain_3.csv "drive/My Drive/BeeChain Foundation/"
