# %% [markdown]
# Created by Joan-Marc Fisa
#
# - Numerai: [FisaGol](https://numer.ai/fisagol)
#
# - Twitter: [@fisagol](https://twitter.com/fisagol)

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
# !pip install numerapi
# !pip install vecstack;
# Out:
# Requirement already satisfied: numerapi in /usr/local/lib/python3.7/dist-packages (2.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from numerapi) (2.23.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from numerapi) (7.1.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from numerapi) (2018.9)
# Requirement already satisfied: tqdm>=4.29.1 in /usr/local/lib/python3.7/dist-packages (from numerapi) (4.62.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from numerapi) (2.8.2)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from numerapi) (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->numerapi) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->numerapi) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->numerapi) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->numerapi) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->numerapi) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->numerapi) (2021.5.30)
# Requirement already satisfied: vecstack in /usr/local/lib/python3.7/dist-packages (0.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.7/dist-packages (from vecstack) (0.22.2.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from vecstack) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18->vecstack) (1.0.1)

# %%
# https://towardsdatascience.com/custom-loss-functions-for-gradient-boosting-f79c1b40466d
# https://github.com/manifoldai/mf-eng-public/blob/master/notebooks/custom_loss_lightgbm.ipynb

# %%
##################################################################
##################### LIBRARIES ##################################
##################################################################

# %%
import numerapi
import os
import gc
import csv
import sys
import glob
import time
from pathlib import Path
from multiprocessing import Pool
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from lightgbm import LGBMRegressor
import lightgbm 
from sklearn.datasets import make_friedman2, make_friedman1, make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import lightgbm
from sklearn.metrics import mean_squared_error
import seaborn as sns; sns.set()
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
def custom_asymmetric_objective(y_true, y_pred):
    residual = (y_true - y_pred).astype("float")
    grad = np.where(residual<0, -2*10.0*residual, -2*residual)
    hess = np.where(residual<0, 2*10.0, 2.0)
    return grad, hess

def custom_asymmetric_eval(y_true, y_pred):
    residual = (y_true - y_pred).astype("float")
    loss = np.where(residual < 0, (residual**2)*10.0, residual**2) 
    return "custom_asymmetric_eval", np.mean(loss), False

# %%
##############################################################################
########################## DOWLOAD DATA ######################################
##############################################################################

# %%
TOURNAMENT_NAME = "nomi"
TARGET_NAME = f"target"
PREDICTION_NAME = f"prediction"

BENCHMARK = 0
BAND = 0.2

# %%
seed = 1
rand = np.random.seed(seed)

# %%
napi = numerapi.NumerAPI(verbosity="info")

napi.download_current_dataset(unzip=True)

current_ds = napi.get_current_round()
latest_round = os.path.join('numerai_dataset_'+str(current_ds))
# Out:
# 2021-09-05 13:21:08,151 INFO numerapi.utils: starting download
# ./numerai_dataset_280.zip:  99%|█████████▉| 416M/420M [00:08<00:00, 51.2MB/s]2021-09-05 13:21:17,071 INFO numerapi.base_api: unzipping file...
# ./numerai_dataset_280.zip: 420MB [00:19, 51.2MB/s]

# %%
##################################################################
##################### LOAD DATA ##################################
##################################################################

# %%
# %%time
print("# Loading data...")

training_data = pd.read_csv(os.path.join(latest_round, "numerai_training_data.csv")).set_index("id")
tournament_data = pd.read_csv(os.path.join(latest_round, "numerai_tournament_data.csv")).set_index("id")
validation_data = tournament_data[tournament_data.data_type == "validation"]

print("# All Loaded...")
# Out:
# ./numerai_dataset_280.zip: 420MB [00:29, 14.0MB/s]
# # Loading data...
# # All Loaded...
# CPU times: user 1min 6s, sys: 11.3 s, total: 1min 17s
# Wall time: 1min 18s

# %%
feature_names = [f for f in training_data.columns if f.startswith("feature")]
print(f"Loaded {len(feature_names)} features")
# Out:
# Loaded 310 features

# %%
X = training_data[feature_names]
Y = training_data[training_data.columns[-1]]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, Y, test_size=0.20, random_state=rand)

# %%
#############################################################################
###########################  CREATING SOME MODELS  ##########################
#############################################################################

# %%
gbm = LGBMRegressor(random_state=rand,early_stopping_rounds = 10,n_estimators=10000)

# %%
gbm.set_params(**{'objective': custom_asymmetric_objective}, metrics = ["mse", 'mae'])
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               early_stopping_rounds=10, importance_type='split',
#               learning_rate=0.1, max_depth=-1, metrics=['mse', 'mae'],
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=10000, n_jobs=-1, num_leaves=31,
#               objective=<function custom_asymmetric_objective at 0x7f1d638c6c20>,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
gbm.fit(
    X_train,
    y_train,
    eval_set=[(X_valid, y_valid)],
    eval_metric=custom_asymmetric_eval,
    verbose=True,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:123: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# 2021-09-05 13:23:00,286 INFO numexpr.utils: Note: NumExpr detected 40 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-09-05 13:23:00,288 INFO numexpr.utils: NumExpr defaulting to 8 threads.
# [1]	valid_0's l1: 0.455254	valid_0's l2: 0.252522	valid_0's custom_asymmetric_eval: 0.253632
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l1: 0.426609	valid_0's l2: 0.225444	valid_0's custom_asymmetric_eval: 0.228035
# [3]	valid_0's l1: 0.400827	valid_0's l2: 0.202832	valid_0's custom_asymmetric_eval: 0.207304
# [4]	valid_0's l1: 0.377615	valid_0's l2: 0.183899	valid_0's custom_asymmetric_eval: 0.190506
# [5]	valid_0's l1: 0.356736	valid_0's l2: 0.168009	valid_0's custom_asymmetric_eval: 0.176901
# [6]	valid_0's l1: 0.337915	valid_0's l2: 0.154625	valid_0's custom_asymmetric_eval: 0.16586
# [7]	valid_0's l1: 0.320912	valid_0's l2: 0.143303	valid_0's custom_asymmetric_eval: 0.156874
# [8]	valid_0's l1: 0.306133	valid_0's l2: 0.133726	valid_0's custom_asymmetric_eval: 0.149613
# [9]	valid_0's l1: 0.295635	valid_0's l2: 0.126684	valid_0's custom_asymmetric_eval: 0.144726
# [10]	valid_0's l1: 0.288163	valid_0's l2: 0.121437	valid_0's custom_asymmetric_eval: 0.141397
# [11]	valid_0's l1: 0.282595	valid_0's l2: 0.117428	valid_0's custom_asymmetric_eval: 0.139061
# [12]	valid_0's l1: 0.278156	valid_0's l2: 0.114174	valid_0's custom_asymmetric_eval: 0.137302
# [13]	valid_0's l1: 0.274475	valid_0's l2: 0.111455	valid_0's custom_asymmetric_eval: 0.135944
# [14]	valid_0's l1: 0.271343	valid_0's l2: 0.109136	valid_0's custom_asymmetric_eval: 0.134887
# [15]	valid_0's l1: 0.268692	valid_0's l2: 0.107164	valid_0's custom_asymmetric_eval: 0.134061
# [16]	valid_0's l1: 0.266396	valid_0's l2: 0.10546	valid_0's custom_asymmetric_eval: 0.133417
# [17]	valid_0's l1: 0.264425	valid_0's l2: 0.103991	valid_0's custom_asymmetric_eval: 0.132897
# [18]	valid_0's l1: 0.262692	valid_0's l2: 0.1027	valid_0's custom_asymmetric_eval: 0.132479
# [19]	valid_0's l1: 0.261181	valid_0's l2: 0.101579	valid_0's custom_asymmetric_eval: 0.132151
# [20]	valid_0's l1: 0.259829	valid_0's l2: 0.100578	valid_0's custom_asymmetric_eval: 0.131881
# [21]	valid_0's l1: 0.258617	valid_0's l2: 0.0996922	valid_0's custom_asymmetric_eval: 0.131653
# [22]	valid_0's l1: 0.257554	valid_0's l2: 0.0989183	valid_0's custom_asymmetric_eval: 0.131465
# [23]	valid_0's l1: 0.2566	valid_0's l2: 0.0982296	valid_0's custom_asymmetric_eval: 0.131307
# [24]	valid_0's l1: 0.255747	valid_0's l2: 0.0976126	valid_0's custom_asymmetric_eval: 0.131184
# [25]	valid_0's l1: 0.254983	valid_0's l2: 0.09706	valid_0's custom_asymmetric_eval: 0.131077
# [26]	valid_0's l1: 0.254306	valid_0's l2: 0.0965613	valid_0's custom_asymmetric_eval: 0.130997
# [27]	valid_0's l1: 0.253692	valid_0's l2: 0.0961194	valid_0's custom_asymmetric_eval: 0.130922
# [28]	valid_0's l1: 0.253147	valid_0's l2: 0.0957301	valid_0's custom_asymmetric_eval: 0.130878
# [29]	valid_0's l1: 0.252647	valid_0's l2: 0.0953681	valid_0's custom_asymmetric_eval: 0.130822
# [30]	valid_0's l1: 0.252205	valid_0's l2: 0.0950488	valid_0's custom_asymmetric_eval: 0.130777
# [31]	valid_0's l1: 0.251803	valid_0's l2: 0.0947688	valid_0's custom_asymmetric_eval: 0.130738
# [32]	valid_0's l1: 0.251454	valid_0's l2: 0.0945184	valid_0's custom_asymmetric_eval: 0.130715
# [33]	valid_0's l1: 0.251131	valid_0's l2: 0.0942867	valid_0's custom_asymmetric_eval: 0.130688
# [34]	valid_0's l1: 0.250838	valid_0's l2: 0.0940807	valid_0's custom_asymmetric_eval: 0.130667
# [35]	valid_0's l1: 0.250562	valid_0's l2: 0.0938884	valid_0's custom_asymmetric_eval: 0.130644
# [36]	valid_0's l1: 0.250324	valid_0's l2: 0.0937245	valid_0's custom_asymmetric_eval: 0.130634
# [37]	valid_0's l1: 0.250101	valid_0's l2: 0.0935743	valid_0's custom_asymmetric_eval: 0.130616
# [38]	valid_0's l1: 0.249898	valid_0's l2: 0.0934366	valid_0's custom_asymmetric_eval: 0.130602
# [39]	valid_0's l1: 0.249722	valid_0's l2: 0.0933185	valid_0's custom_asymmetric_eval: 0.130597
# [40]	valid_0's l1: 0.249558	valid_0's l2: 0.0932052	valid_0's custom_asymmetric_eval: 0.13059
# [41]	valid_0's l1: 0.249406	valid_0's l2: 0.0931015	valid_0's custom_asymmetric_eval: 0.130582
# [42]	valid_0's l1: 0.249258	valid_0's l2: 0.0930064	valid_0's custom_asymmetric_eval: 0.130564
# [43]	valid_0's l1: 0.249132	valid_0's l2: 0.0929209	valid_0's custom_asymmetric_eval: 0.130556
# [44]	valid_0's l1: 0.249026	valid_0's l2: 0.0928371	valid_0's custom_asymmetric_eval: 0.130554
# [45]	valid_0's l1: 0.248925	valid_0's l2: 0.0927628	valid_0's custom_asymmetric_eval: 0.130555
# [46]	valid_0's l1: 0.248827	valid_0's l2: 0.0926921	valid_0's custom_asymmetric_eval: 0.130553
# [47]	valid_0's l1: 0.248736	valid_0's l2: 0.0926289	valid_0's custom_asymmetric_eval: 0.130552
# [48]	valid_0's l1: 0.248648	valid_0's l2: 0.0925728	valid_0's custom_asymmetric_eval: 0.130543
# [49]	valid_0's l1: 0.248575	valid_0's l2: 0.0925246	valid_0's custom_asymmetric_eval: 0.130542
# [50]	valid_0's l1: 0.248512	valid_0's l2: 0.0924781	valid_0's custom_asymmetric_eval: 0.130545
# [51]	valid_0's l1: 0.248439	valid_0's l2: 0.0924345	valid_0's custom_asymmetric_eval: 0.130541
# [52]	valid_0's l1: 0.248379	valid_0's l2: 0.0923951	valid_0's custom_asymmetric_eval: 0.130536
# [53]	valid_0's l1: 0.248331	valid_0's l2: 0.0923569	valid_0's custom_asymmetric_eval: 0.130535
# [54]	valid_0's l1: 0.248277	valid_0's l2: 0.0923271	valid_0's custom_asymmetric_eval: 0.130532
# [55]	valid_0's l1: 0.248223	valid_0's l2: 0.0922916	valid_0's custom_asymmetric_eval: 0.130524
# [56]	valid_0's l1: 0.248172	valid_0's l2: 0.0922617	valid_0's custom_asymmetric_eval: 0.130519
# [57]	valid_0's l1: 0.248139	valid_0's l2: 0.092238	valid_0's custom_asymmetric_eval: 0.130528
# [58]	valid_0's l1: 0.248101	valid_0's l2: 0.092211	valid_0's custom_asymmetric_eval: 0.130525
# [59]	valid_0's l1: 0.248058	valid_0's l2: 0.0921907	valid_0's custom_asymmetric_eval: 0.130515
# [60]	valid_0's l1: 0.248036	valid_0's l2: 0.0921681	valid_0's custom_asymmetric_eval: 0.130529
# [61]	valid_0's l1: 0.248004	valid_0's l2: 0.0921461	valid_0's custom_asymmetric_eval: 0.130527
# [62]	valid_0's l1: 0.247971	valid_0's l2: 0.0921205	valid_0's custom_asymmetric_eval: 0.130524
# [63]	valid_0's l1: 0.247929	valid_0's l2: 0.0921028	valid_0's custom_asymmetric_eval: 0.130524
# [64]	valid_0's l1: 0.247888	valid_0's l2: 0.0920797	valid_0's custom_asymmetric_eval: 0.13052
# [65]	valid_0's l1: 0.247854	valid_0's l2: 0.092063	valid_0's custom_asymmetric_eval: 0.130513
# [66]	valid_0's l1: 0.247831	valid_0's l2: 0.0920463	valid_0's custom_asymmetric_eval: 0.13051
# [67]	valid_0's l1: 0.247804	valid_0's l2: 0.0920291	valid_0's custom_asymmetric_eval: 0.130509
# [68]	valid_0's l1: 0.247785	valid_0's l2: 0.0920144	valid_0's custom_asymmetric_eval: 0.130509
# [69]	valid_0's l1: 0.247759	valid_0's l2: 0.0919965	valid_0's custom_asymmetric_eval: 0.130502
# [70]	valid_0's l1: 0.247737	valid_0's l2: 0.0919823	valid_0's custom_asymmetric_eval: 0.130507
# [71]	valid_0's l1: 0.247715	valid_0's l2: 0.0919664	valid_0's custom_asymmetric_eval: 0.13051
# [72]	valid_0's l1: 0.247701	valid_0's l2: 0.0919549	valid_0's custom_asymmetric_eval: 0.130516
# [73]	valid_0's l1: 0.247682	valid_0's l2: 0.0919453	valid_0's custom_asymmetric_eval: 0.130526
# [74]	valid_0's l1: 0.247666	valid_0's l2: 0.0919287	valid_0's custom_asymmetric_eval: 0.130527
# [75]	valid_0's l1: 0.247641	valid_0's l2: 0.0919122	valid_0's custom_asymmetric_eval: 0.130523
# [76]	valid_0's l1: 0.247623	valid_0's l2: 0.0919011	valid_0's custom_asymmetric_eval: 0.130522
# [77]	valid_0's l1: 0.247605	valid_0's l2: 0.0918907	valid_0's custom_asymmetric_eval: 0.130521
# [78]	valid_0's l1: 0.247584	valid_0's l2: 0.0918719	valid_0's custom_asymmetric_eval: 0.130518
# [79]	valid_0's l1: 0.247564	valid_0's l2: 0.0918645	valid_0's custom_asymmetric_eval: 0.130514
# Early stopping, best iteration is:
# [69]	valid_0's l1: 0.247759	valid_0's l2: 0.0919965	valid_0's custom_asymmetric_eval: 0.130502
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               early_stopping_rounds=10, importance_type='split',
#               learning_rate=0.1, max_depth=-1, metrics=['mse', 'mae'],
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=10000, n_jobs=-1, num_leaves=31,
#               objective=<function custom_asymmetric_objective at 0x7f1d638c6c20>,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
# %%time
y_pred_model = gbm.predict(tournament_data[feature_names])
gc.collect()

tournament_data[PREDICTION_NAME] = y_pred_model
# Out:
# CPU times: user 25.8 s, sys: 3.35 s, total: 29.2 s
# Wall time: 8.3 s

# %%
tournament_data[PREDICTION_NAME]
# Out:
# id
# n0003aa52cab36c2    0.315867
# n000920ed083903f    0.290415
# n0038e640522c4a6    0.243681
# n004ac94a87dc54b    0.310756
# n0052fe97ea0c05f    0.327616
#                       ...
# nffcc555b6bc06aa    0.235904
# nffcfd14874a15c4    0.310414
# nffdb0b5a746c4f7    0.282280
# nffecef421ac6791    0.313469
# nfff39308bdddb48    0.302644
# Name: prediction, Length: 1806285, dtype: float64

# %%
def neutralize(df, columns, by, proportion=1.0):
  
    scores = df[columns]
    exposures = df[by].values
    # constant column to make sure the series is completely neutral to exposures
    exposures = np.hstack((exposures, np.array([np.mean(scores)] * len(exposures)).reshape(-1, 1)))
    gc.collect()
    scores = scores - proportion * exposures.dot(np.linalg.pinv(exposures).dot(scores))
    gc.collect()
    return scores / scores.std()

# %%
# %%time
tournament_data[PREDICTION_NAME] = neutralize(tournament_data, PREDICTION_NAME, feature_names)
# Out:
# CPU times: user 8min 38s, sys: 8min 39s, total: 17min 17s
# Wall time: 47.5 s

# %%
def minmax_norm(df):
    return (df - df.min()) / (df.max() - df.min())

# %%
tournament_data[PREDICTION_NAME] = minmax_norm(tournament_data[PREDICTION_NAME])

# %%
tournament_data[PREDICTION_NAME]
# Out:
# id
# n0003aa52cab36c2    0.546585
# n000920ed083903f    0.534937
# n0038e640522c4a6    0.424623
# n004ac94a87dc54b    0.502969
# n0052fe97ea0c05f    0.411100
#                       ...
# nffcc555b6bc06aa    0.306967
# nffcfd14874a15c4    0.371504
# nffdb0b5a746c4f7    0.539881
# nffecef421ac6791    0.454630
# nfff39308bdddb48    0.490544
# Name: prediction, Length: 1806285, dtype: float64

# %%
##############################################################################
######################### MAKE SUBMISSION #################################### 
##############################################################################

# %%
tournament_data[PREDICTION_NAME].to_csv('BeeChain_4.csv')

# !cp BeeChain_4.csv "drive/My Drive/BeeChain Foundation/"
